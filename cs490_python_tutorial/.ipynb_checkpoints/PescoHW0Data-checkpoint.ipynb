# %%
# %matplotlib inline
import numpy as np
from numpy.random import randn
import matplotlib.pyplot as plt
import scipy.io

import scipy.misc
import imageio

# %%
data = np.loadtxt('winequality-red.csv', delimiter=',')

# %%
for x in range (11):
    fig, axes = plt.subplots(1,1)
    axes.plot(data[:,x],data[:,11], 'r.')
